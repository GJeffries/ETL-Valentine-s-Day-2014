# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "valentines_day_2014.csv"
output = pd.read_csv(output_data_file)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
all_cities = []


# Create a set of random lat and lng combinations
lats = output["Latitude"]
lngs = output["Longitude"]
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    all_cities.append(city)
    
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 223

# %%
cities
# Out:
# ['london',
#  'loughton',
#  'brentwood',
#  'dartford',
#  'borehamwood',
#  'potters bar',
#  'leatherhead',
#  'sunbury',
#  'watford',
#  'staines',
#  'cheshunt',
#  'reigate',
#  'fleetwood',
#  'workington',
#  'carlisle',
#  'whitehaven',
#  'ormskirk',
#  'preston',
#  'blackburn',
#  'accrington',
#  'burnley',
#  'wallasey',
#  'litherland',
#  'kirkby',
#  'saint helens',
#  'liverpool',
#  'prescot',
#  'manchester',
#  'eccles',
#  'walkden',
#  'prestwich',
#  'oldham',
#  'rawtenstall',
#  'wilmslow',
#  'northwich',
#  'crewe',
#  'macclesfield',
#  'ashington',
#  'jarrow',
#  'north shields',
#  'newcastle upon tyne',
#  'gateshead',
#  'south shields',
#  'darlington',
#  'newton aycliffe',
#  'redcar',
#  'york',
#  'harrogate',
#  'leeds',
#  'castleford',
#  'keighley',
#  'huddersfield',
#  'halifax',
#  'shipley',
#  'brighouse',
#  'bradford',
#  'bentley',
#  'doncaster',
#  'rotherham',
#  'chapeltown',
#  'sheffield',
#  'dronfield',
#  'grimsby',
# ...

# %%
len(all_cities)
# Out:
# 426

# %%
all_cities
# Out:
# ['london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'loughton',
#  'loughton',
#  'loughton',
#  'brentwood',
#  'dartford',
#  'london',
#  'loughton',
#  'london',
#  'london',
#  'loughton',
#  'london',
#  'loughton',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'dartford',
#  'london',
#  'borehamwood',
#  'borehamwood',
#  'borehamwood',
#  'london',
#  'borehamwood',
#  'borehamwood',
#  'borehamwood',
#  'potters bar',
#  'borehamwood',
#  'leatherhead',
#  'london',
#  'sunbury',
#  'sunbury',
#  'sunbury',
#  'sunbury',
#  'sunbury',
#  'sunbury',
#  'sunbury',
#  'leatherhead',
#  'leatherhead',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
#  'london',
# ...

# %%
output["City"] = all_cities

# %%
clean_df = output[["Accident_Index", "Longitude", "Latitude", "City"]]
clean_df
# Out:
#     Accident_Index  Longitude   Latitude          City
# 0    201401BS70078  -0.193863  51.504785        london
# 1    201401BS70080  -0.202646  51.497636        london
# 2    201401CW10146  -0.157572  51.522116        london
# 3    201401CW10147  -0.172955  51.526763        london
# 4    201401CW10155  -0.173844  51.522550        london
# ..             ...        ...        ...           ...
# 421  201497UA02802  -4.702039  55.653904    kilwinning
# 422  201497UA03602  -4.859646  55.787867         largs
# 423  201497UD02502  -4.629989  55.467655           ayr
# 424       2.01E+12  -3.601195  55.067726  locharbriggs
# 425       2.01E+12  -3.520899  55.385802        moffat
#
# [426 rows x 4 columns]

# %%
clean_df.to_csv("accident_cities.csv", index = False)
